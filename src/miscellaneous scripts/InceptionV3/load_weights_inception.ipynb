# %%
from keras.applications.inception_v3 import InceptionV3

# %%
model = InceptionV3(weights='imagenet', include_top=False, input_shape=(256,256,3))
#model.summary()

# %%
#freeze layer you don't want to train. Here I'm freezing the first 10 layers.
for layer in model.layers[:10]:
    layer.trainable = False

# %%
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D

#Adding custom layers
x = model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(5, activation='softmax')(x)

# %%
# Creating Final model 
model_final = Model(inputs = model.input, outputs= predictions)
#model_final.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 127, 127, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 127, 127, 32) 96          conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 127, 127, 32) 0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 125, 125, 32) 9216        activation_189[0][0]
# ...

# %%
from keras.utils import plot_model
#modele = InceptionV3(weights='imagenet', include_top=True, input_shape=(256,256,3))
plot_model(model, to_file='model_without_top.png')
